# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import OpenWeather_API_KEY

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + OpenWeather_API_KEY
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=37fa808393b886cd0345e65fd276a8a8'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_description = city_weather["weather"][0]['description']

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | tabou
# Processing Record 4 of Set 1 | marsh harbour
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | bathsheba
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | sinop
# Processing Record 9 of Set 1 | luangwa
# Processing Record 10 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 1 | bonavista
# Processing Record 12 of Set 1 | emborion
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | cruzeiro do sul
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | codrington
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | souillac
# Processing Record 20 of Set 1 | inta
# Processing Record 21 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 1 | big bend
# Processing Record 23 of Set 1 | coquimbo
# Processing Record 24 of Set 1 | sebring
# Processing Record 25 of Set 1 | voronezhskaya
# Processing Record 26 of Set 1 | bahia blanca
# Processing Record 27 of Set 1 | kastamonu
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | claremorris
# Processing Record 30 of Set 1 | athens
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | nouadhibou
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 1 | sioux lookout
# Processing Record 37 of Set 1 | maceio
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | vestmannaeyjar
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | saldanha
# Processing Record 42 of Set 1 | iracoubo
# Processing Record 43 of Set 1 | margate
# Processing Record 44 of Set 1 | victoria
# Processing Record 45 of Set 1 | talara
# Processing Record 46 of Set 1 | lasa
# Processing Record 47 of Set 1 | jalu
# Processing Record 48 of Set 1 | cayenne
# Processing Record 49 of Set 1 | arroyo
# Processing Record 50 of Set 1 | talnakh
# Processing Record 1 of Set 2 | faya
# Processing Record 2 of Set 2 | svetlogorsk
# Processing Record 3 of Set 2 | nanortalik
# Processing Record 4 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 2 | campo grande
# Processing Record 6 of Set 2 | itaiba
# Processing Record 7 of Set 2 | richards bay
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | umarkot
# Processing Record 13 of Set 2 | sao joao da barra
# Processing Record 14 of Set 2 | abrau-dyurso
# Processing Record 15 of Set 2 | williamsburg
# Processing Record 16 of Set 2 | pangnirtung
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 2 | mehamn
# Processing Record 20 of Set 2 | adamas
# Processing Record 21 of Set 2 | paamiut
# Processing Record 22 of Set 2 | outjo
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | liverpool
# Processing Record 25 of Set 2 | matara
# Processing Record 26 of Set 2 | nieuw amsterdam
# Processing Record 27 of Set 2 | stamsund
# City not found. Skipping...
# Processing Record 28 of Set 2 | hamilton
# Processing Record 29 of Set 2 | sabha
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | los andes
# Processing Record 32 of Set 2 | coihaique
# Processing Record 33 of Set 2 | port-gentil
# Processing Record 34 of Set 2 | visby
# Processing Record 35 of Set 2 | motru
# Processing Record 36 of Set 2 | luba
# Processing Record 37 of Set 2 | namibe
# Processing Record 38 of Set 2 | caravelas
# Processing Record 39 of Set 2 | grindavik
# Processing Record 40 of Set 2 | nabul
# City not found. Skipping...
# Processing Record 41 of Set 2 | turukhansk
# Processing Record 42 of Set 2 | hobyo
# Processing Record 43 of Set 2 | chiredzi
# Processing Record 44 of Set 2 | oltu
# Processing Record 45 of Set 2 | teguldet
# Processing Record 46 of Set 2 | mehkerek
# Processing Record 47 of Set 2 | qaqortoq
# Processing Record 48 of Set 2 | wilson
# Processing Record 49 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 1 of Set 3 | aasiaat
# Processing Record 2 of Set 3 | nara
# Processing Record 3 of Set 3 | tabas
# Processing Record 4 of Set 3 | alpena
# Processing Record 5 of Set 3 | kuyanovo
# Processing Record 6 of Set 3 | pontes e lacerda
# Processing Record 7 of Set 3 | padang
# Processing Record 8 of Set 3 | torbay
# Processing Record 9 of Set 3 | parrita
# Processing Record 10 of Set 3 | sabla
# Processing Record 11 of Set 3 | inhambane
# Processing Record 12 of Set 3 | clearwater
# Processing Record 13 of Set 3 | dhankuta
# Processing Record 14 of Set 3 | ipubi
# Processing Record 15 of Set 3 | olafsvik
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | chapais
# Processing Record 19 of Set 3 | antofagasta
# Processing Record 20 of Set 3 | esil
# Processing Record 21 of Set 3 | vigrestad
# Processing Record 22 of Set 3 | kruisfontein
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | cidreira
# Processing Record 25 of Set 3 | scarborough
# Processing Record 26 of Set 3 | draguignan
# Processing Record 27 of Set 3 | sfantu gheorghe
# Processing Record 28 of Set 3 | moose factory
# Processing Record 29 of Set 3 | igarka
# Processing Record 30 of Set 3 | abalak
# Processing Record 31 of Set 3 | san cristobal
# Processing Record 32 of Set 3 | porto nacional
# Processing Record 33 of Set 3 | krasnovishersk
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | panama city
# Processing Record 37 of Set 3 | parys
# Processing Record 38 of Set 3 | rocha
# Processing Record 39 of Set 3 | nyandoma
# Processing Record 40 of Set 3 | rio grande
# Processing Record 41 of Set 3 | ramsar
# Processing Record 42 of Set 3 | saint george
# Processing Record 43 of Set 3 | bella union
# Processing Record 44 of Set 3 | thinadhoo
# Processing Record 45 of Set 3 | sinnamary
# Processing Record 46 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 3 | camacha
# Processing Record 48 of Set 3 | abu samrah
# Processing Record 49 of Set 3 | parnarama
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | sayyan
# Processing Record 2 of Set 4 | taoudenni
# Processing Record 3 of Set 4 | peniche
# Processing Record 4 of Set 4 | keuruu
# Processing Record 5 of Set 4 | boyabat
# Processing Record 6 of Set 4 | sehwan
# Processing Record 7 of Set 4 | javanrud
# Processing Record 8 of Set 4 | hambantota
# Processing Record 9 of Set 4 | katwijk
# Processing Record 10 of Set 4 | saint-pierre
# Processing Record 11 of Set 4 | bria
# Processing Record 12 of Set 4 | semenivka
# Processing Record 13 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 4 | quepos
# Processing Record 15 of Set 4 | tombouctou
# Processing Record 16 of Set 4 | odweyne
# Processing Record 17 of Set 4 | borlange
# City not found. Skipping...
# Processing Record 18 of Set 4 | tarnos
# Processing Record 19 of Set 4 | tyup
# Processing Record 20 of Set 4 | hire
# City not found. Skipping...
# Processing Record 21 of Set 4 | valparaiso
# Processing Record 22 of Set 4 | houlton
# Processing Record 23 of Set 4 | kalisz
# Processing Record 24 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 4 | finote selam
# Processing Record 26 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 4 | ipojuca
# Processing Record 28 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 4 | kambove
# Processing Record 30 of Set 4 | eyl
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | soligalich
# Processing Record 33 of Set 4 | salalah
# Processing Record 34 of Set 4 | havoysund
# Processing Record 35 of Set 4 | nadym
# Processing Record 36 of Set 4 | arraial do cabo
# Processing Record 37 of Set 4 | baghmara
# Processing Record 38 of Set 4 | aksu
# Processing Record 39 of Set 4 | luderitz
# Processing Record 40 of Set 4 | chuy
# Processing Record 41 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 42 of Set 4 | sisimiut
# Processing Record 43 of Set 4 | comodoro rivadavia
# Processing Record 44 of Set 4 | wattegama
# Processing Record 45 of Set 4 | manono
# Processing Record 46 of Set 4 | opobo
# City not found. Skipping...
# Processing Record 47 of Set 4 | osakarovka
# Processing Record 48 of Set 4 | buraydah
# Processing Record 49 of Set 4 | cerro de pasco
# Processing Record 50 of Set 4 | vila velha
# Processing Record 1 of Set 5 | forchheim
# Processing Record 2 of Set 5 | kamyshla
# Processing Record 3 of Set 5 | bandarbeyla
# Processing Record 4 of Set 5 | ibotirama
# Processing Record 5 of Set 5 | boa vista
# Processing Record 6 of Set 5 | mbandaka
# Processing Record 7 of Set 5 | nikel
# Processing Record 8 of Set 5 | yar-sale
# Processing Record 9 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 5 | hithadhoo
# Processing Record 11 of Set 5 | algiers
# Processing Record 12 of Set 5 | saint-augustin
# Processing Record 13 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 5 | narsaq
# Processing Record 15 of Set 5 | touros
# Processing Record 16 of Set 5 | lerwick
# Processing Record 17 of Set 5 | oktyabrskoye
# Processing Record 18 of Set 5 | itarema
# Processing Record 19 of Set 5 | rio gallegos
# Processing Record 20 of Set 5 | ostrovnoy
# Processing Record 21 of Set 5 | havre-saint-pierre
# Processing Record 22 of Set 5 | harper
# Processing Record 23 of Set 5 | at-bashi
# Processing Record 24 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 5 | lalibela
# Processing Record 26 of Set 5 | yining
# Processing Record 27 of Set 5 | veinticinco de mayo
# Processing Record 28 of Set 5 | marfino
# Processing Record 29 of Set 5 | severnyy
# Processing Record 30 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 31 of Set 5 | salym
# Processing Record 32 of Set 5 | akhisar
# Processing Record 33 of Set 5 | mineiros
# Processing Record 34 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 35 of Set 5 | klaksvik
# Processing Record 36 of Set 5 | general pico
# Processing Record 37 of Set 5 | atbasar
# Processing Record 38 of Set 5 | mangai
# Processing Record 39 of Set 5 | mao
# Processing Record 40 of Set 5 | upala
# Processing Record 41 of Set 5 | san vicente de canete
# Processing Record 42 of Set 5 | atar
# Processing Record 43 of Set 5 | kulhudhuffushi
# Processing Record 44 of Set 5 | tsogni
# Processing Record 45 of Set 5 | qarayeri
# Processing Record 46 of Set 5 | lincoln
# Processing Record 47 of Set 5 | gat
# Processing Record 48 of Set 5 | quixeramobim
# Processing Record 49 of Set 5 | camana
# Processing Record 50 of Set 5 | lilongwe
# Processing Record 1 of Set 6 | gazanjyk
# Processing Record 2 of Set 6 | tocache
# Processing Record 3 of Set 6 | khor
# Processing Record 4 of Set 6 | yurginskoye
# Processing Record 5 of Set 6 | mitsamiouli
# Processing Record 6 of Set 6 | chitral
# Processing Record 7 of Set 6 | geraldton
# Processing Record 8 of Set 6 | zhitikara
# City not found. Skipping...
# Processing Record 9 of Set 6 | derzhavinsk
# Processing Record 10 of Set 6 | paratinga
# Processing Record 11 of Set 6 | westport
# Processing Record 12 of Set 6 | la asuncion
# Processing Record 13 of Set 6 | cockburn town
# Processing Record 14 of Set 6 | agucadoura
# Processing Record 15 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | chipata
# Processing Record 18 of Set 6 | necochea
# Processing Record 19 of Set 6 | inza
# Processing Record 20 of Set 6 | mahibadhoo
# Processing Record 21 of Set 6 | henties bay
# Processing Record 22 of Set 6 | araouane
# Processing Record 23 of Set 6 | los llanos de aridane
# Processing Record 24 of Set 6 | bengkulu
# Processing Record 25 of Set 6 | baile olanesti
# Processing Record 26 of Set 6 | machaneng
# Processing Record 27 of Set 6 | koindu
# Processing Record 28 of Set 6 | severomorsk
# Processing Record 29 of Set 6 | ketchenery
# City not found. Skipping...
# Processing Record 30 of Set 6 | pervomayskoye
# Processing Record 31 of Set 6 | horta
# Processing Record 32 of Set 6 | beloha
# Processing Record 33 of Set 6 | pomabamba
# Processing Record 34 of Set 6 | puerto lempira
# Processing Record 35 of Set 6 | lobez
# Processing Record 36 of Set 6 | bafq
# Processing Record 37 of Set 6 | pimenta bueno
# Processing Record 38 of Set 6 | dakar
# Processing Record 39 of Set 6 | san andres
# Processing Record 40 of Set 6 | morton
# Processing Record 41 of Set 6 | ponta delgada
# Processing Record 42 of Set 6 | roald
# Processing Record 43 of Set 6 | filadelfia
# Processing Record 44 of Set 6 | skibbereen
# Processing Record 45 of Set 6 | bennington
# Processing Record 46 of Set 6 | carballo
# Processing Record 47 of Set 6 | bollnas
# Processing Record 48 of Set 6 | miraflores
# Processing Record 49 of Set 6 | dingle
# Processing Record 50 of Set 6 | phalaborwa
# Processing Record 1 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 7 | port blair
# Processing Record 3 of Set 7 | opuwo
# Processing Record 4 of Set 7 | raudeberg
# Processing Record 5 of Set 7 | nuuk
# Processing Record 6 of Set 7 | doaba
# Processing Record 7 of Set 7 | tatarsk
# Processing Record 8 of Set 7 | kita
# Processing Record 9 of Set 7 | verkhnyaya toyma
# Processing Record 10 of Set 7 | santa rosa
# Processing Record 11 of Set 7 | vardo
# Processing Record 12 of Set 7 | mandera
# Processing Record 13 of Set 7 | sikasso
# Processing Record 14 of Set 7 | gilbues
# Processing Record 15 of Set 7 | marawi
# Processing Record 16 of Set 7 | bocas del toro
# Processing Record 17 of Set 7 | husavik
# Processing Record 18 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 7 | pafos
# Processing Record 20 of Set 7 | katastarion
# Processing Record 21 of Set 7 | ebes
# Processing Record 22 of Set 7 | praia da vitoria
# Processing Record 23 of Set 7 | clyde river
# Processing Record 24 of Set 7 | maniitsoq
# Processing Record 25 of Set 7 | stornoway
# Processing Record 26 of Set 7 | havant
# Processing Record 27 of Set 7 | izazi
# Processing Record 28 of Set 7 | muzhi
# Processing Record 29 of Set 7 | bitkine
# Processing Record 30 of Set 7 | azar shahr
# City not found. Skipping...
# Processing Record 31 of Set 7 | pocone
# Processing Record 32 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 7 | porto santo
# Processing Record 34 of Set 7 | santa fe
# Processing Record 35 of Set 7 | gardenstown
# Processing Record 36 of Set 7 | le port
# Processing Record 37 of Set 7 | arrifes
# Processing Record 38 of Set 7 | emba
# Processing Record 39 of Set 7 | gravdal
# Processing Record 40 of Set 7 | saint anthony
# Processing Record 41 of Set 7 | mananjary
# Processing Record 42 of Set 7 | bukama
# Processing Record 43 of Set 7 | leo
# Processing Record 44 of Set 7 | tandalti
# Processing Record 45 of Set 7 | keflavik
# Processing Record 46 of Set 7 | mana
# Processing Record 47 of Set 7 | damghan
# Processing Record 48 of Set 7 | rudbar
# Processing Record 49 of Set 7 | bonthe
# Processing Record 50 of Set 7 | hwange
# Processing Record 1 of Set 8 | kulu
# Processing Record 2 of Set 8 | chapleau
# Processing Record 3 of Set 8 | kalakamati
# Processing Record 4 of Set 8 | puri
# Processing Record 5 of Set 8 | envira
# Processing Record 6 of Set 8 | san luis
# Processing Record 7 of Set 8 | inzer
# Processing Record 8 of Set 8 | carrigaline
# Processing Record 9 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 10 of Set 8 | hualmay
# Processing Record 11 of Set 8 | monteagudo
# Processing Record 12 of Set 8 | syracuse
# Processing Record 13 of Set 8 | dubti
# Processing Record 14 of Set 8 | macapa
# Processing Record 15 of Set 8 | surt
# Processing Record 16 of Set 8 | carmagnola
# Processing Record 17 of Set 8 | agadez
# Processing Record 18 of Set 8 | akcakoca
# Processing Record 19 of Set 8 | bay roberts
# Processing Record 20 of Set 8 | brae
# Processing Record 21 of Set 8 | mogochin
# City not found. Skipping...
# Processing Record 22 of Set 8 | dalbandin
# Processing Record 23 of Set 8 | wabana
# Processing Record 24 of Set 8 | puerto quijarro
# Processing Record 25 of Set 8 | blois
# Processing Record 26 of Set 8 | sipe sipe
# Processing Record 27 of Set 8 | cabrero
# Processing Record 28 of Set 8 | llangefni
# Processing Record 29 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 30 of Set 8 | minab
# Processing Record 31 of Set 8 | vossevangen
# Processing Record 32 of Set 8 | ayagoz
# Processing Record 33 of Set 8 | sol-iletsk
# Processing Record 34 of Set 8 | burica
# City not found. Skipping...
# Processing Record 35 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 8 | goderich
# Processing Record 37 of Set 8 | portsmouth
# Processing Record 38 of Set 8 | aden
# Processing Record 39 of Set 8 | vilhena
# Processing Record 40 of Set 8 | phalombe
# Processing Record 41 of Set 8 | kharp
# Processing Record 42 of Set 8 | tocopilla
# Processing Record 43 of Set 8 | zemio
# Processing Record 44 of Set 8 | saquarema
# Processing Record 45 of Set 8 | dudinka
# Processing Record 46 of Set 8 | santa vitoria do palmar
# Processing Record 47 of Set 8 | karaton
# Processing Record 48 of Set 8 | leshukonskoye
# Processing Record 49 of Set 8 | clarence town
# Processing Record 50 of Set 8 | krasnoselkup
# Processing Record 1 of Set 9 | maldonado
# Processing Record 2 of Set 9 | fethiye
# Processing Record 3 of Set 9 | kaduqli
# Processing Record 4 of Set 9 | muros
# Processing Record 5 of Set 9 | salinopolis
# Processing Record 6 of Set 9 | belmonte
# Processing Record 7 of Set 9 | chicama
# Processing Record 8 of Set 9 | camapua
# Processing Record 9 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 9 | ouargaye
# Processing Record 11 of Set 9 | tougue
# Processing Record 12 of Set 9 | barao de melgaco
# Processing Record 13 of Set 9 | kapoeta
# Processing Record 14 of Set 9 | marystown
# Processing Record 15 of Set 9 | artigas
# Processing Record 16 of Set 9 | ambilobe
# Processing Record 17 of Set 9 | ginda
# Processing Record 18 of Set 9 | abu kamal
# Processing Record 19 of Set 9 | carahue
# Processing Record 20 of Set 9 | sept-iles
# Processing Record 21 of Set 9 | pascagoula
# Processing Record 22 of Set 9 | villa alemana
# Processing Record 23 of Set 9 | tatui
# Processing Record 24 of Set 9 | yaypan
# Processing Record 25 of Set 9 | aswan
# Processing Record 26 of Set 9 | mazarron
# Processing Record 27 of Set 9 | oboyan
# Processing Record 28 of Set 9 | vylkove
# Processing Record 29 of Set 9 | itaituba
# Processing Record 30 of Set 9 | lethem
# Processing Record 31 of Set 9 | upington
# Processing Record 32 of Set 9 | skjervoy
# Processing Record 33 of Set 9 | bilma
# Processing Record 34 of Set 9 | susah
# City not found. Skipping...
# Processing Record 35 of Set 9 | adrar
# Processing Record 36 of Set 9 | nassau
# Processing Record 37 of Set 9 | nchelenge
# Processing Record 38 of Set 9 | maine-soroa
# Processing Record 39 of Set 9 | lagoa
# Processing Record 40 of Set 9 | independence
# Processing Record 41 of Set 9 | tarabha
# Processing Record 42 of Set 9 | carnarvon
# Processing Record 43 of Set 9 | swidnik
# Processing Record 44 of Set 9 | rudnichnyy
# Processing Record 45 of Set 9 | waddan
# Processing Record 46 of Set 9 | marzuq
# Processing Record 47 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 9 | mhlume
# Processing Record 49 of Set 9 | murcia
# Processing Record 50 of Set 9 | thompson
# Processing Record 1 of Set 10 | amapa
# Processing Record 2 of Set 10 | pastavy
# Processing Record 3 of Set 10 | sao joao de pirabas
# Processing Record 4 of Set 10 | carutapera
# Processing Record 5 of Set 10 | lodwar
# Processing Record 6 of Set 10 | hofn
# Processing Record 7 of Set 10 | lusambo
# Processing Record 8 of Set 10 | george town
# Processing Record 9 of Set 10 | palakollu
# Processing Record 10 of Set 10 | tazovskiy
# Processing Record 11 of Set 10 | qasigiannguit
# Processing Record 12 of Set 10 | qunduz
# Processing Record 13 of Set 10 | shahdadpur
# Processing Record 14 of Set 10 | sestri levante
# Processing Record 15 of Set 10 | viru
# Processing Record 16 of Set 10 | tekeli
# Processing Record 17 of Set 10 | crato
# Processing Record 18 of Set 10 | gusau
# Processing Record 19 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 10 | nador
# Processing Record 21 of Set 10 | cochrane
# Processing Record 22 of Set 10 | semirom
# Processing Record 23 of Set 10 | ashford
# Processing Record 24 of Set 10 | teya
# Processing Record 25 of Set 10 | solwezi
# Processing Record 26 of Set 10 | basse
# Processing Record 27 of Set 10 | namwala
# Processing Record 28 of Set 10 | bataipora
# Processing Record 29 of Set 10 | ondjiva
# Processing Record 30 of Set 10 | arivonimamo
# Processing Record 31 of Set 10 | sao felix do xingu
# Processing Record 32 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 33 of Set 10 | jamai
# Processing Record 34 of Set 10 | mizdah
# Processing Record 35 of Set 10 | sorland
# Processing Record 36 of Set 10 | diamantino
# Processing Record 37 of Set 10 | edgewater
# Processing Record 38 of Set 10 | kankakee
# Processing Record 39 of Set 10 | kamina
# Processing Record 40 of Set 10 | pisco
# Processing Record 41 of Set 10 | lephepe
# City not found. Skipping...
# Processing Record 42 of Set 10 | urumqi
# Processing Record 43 of Set 10 | carinhanha
# Processing Record 44 of Set 10 | zaykovo
# Processing Record 45 of Set 10 | sundargarh
# Processing Record 46 of Set 10 | ampanihy
# Processing Record 47 of Set 10 | bonwapitse
# Processing Record 48 of Set 10 | kavaratti
# Processing Record 49 of Set 10 | werda
# Processing Record 50 of Set 10 | jacareacanga
# Processing Record 1 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 11 | laguna
# Processing Record 3 of Set 11 | atouguia da baleia
# Processing Record 4 of Set 11 | lovozero
# Processing Record 5 of Set 11 | dombasle-sur-meurthe
# Processing Record 6 of Set 11 | zanjan
# Processing Record 7 of Set 11 | plettenberg bay
# Processing Record 8 of Set 11 | muscat
# Processing Record 9 of Set 11 | zatyshshya
# Processing Record 10 of Set 11 | berlevag
# Processing Record 11 of Set 11 | sharon
# Processing Record 12 of Set 11 | saint-joseph
# Processing Record 13 of Set 11 | bembereke
# Processing Record 14 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 11 | vila franca do campo
# Processing Record 16 of Set 11 | grand gaube
# Processing Record 17 of Set 11 | harnosand
# Processing Record 18 of Set 11 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 19 of Set 11 | huarmey
# Processing Record 20 of Set 11 | tsabong
# Processing Record 21 of Set 11 | fereydun kenar
# Processing Record 22 of Set 11 | jurmala
# Processing Record 23 of Set 11 | hare bay
# Processing Record 24 of Set 11 | saint-francois
# Processing Record 25 of Set 11 | borkenes
# Processing Record 26 of Set 11 | axixa do tocantins
# City not found. Skipping...
# Processing Record 27 of Set 11 | ugoofaaru
# Processing Record 28 of Set 11 | sumbawanga
# Processing Record 29 of Set 11 | ibipeba
# Processing Record 30 of Set 11 | letnyaya stavka
# Processing Record 31 of Set 11 | ankazobe
# Processing Record 32 of Set 11 | iglesias
# Processing Record 33 of Set 11 | altay
# Processing Record 34 of Set 11 | umm lajj
# Processing Record 35 of Set 11 | puerto madryn
# Processing Record 36 of Set 11 | meulaboh
# Processing Record 37 of Set 11 | vozhega
# Processing Record 38 of Set 11 | tpig
# Processing Record 39 of Set 11 | arkhangelsk
# Processing Record 40 of Set 11 | nicoya
# Processing Record 41 of Set 11 | glubokiy
# Processing Record 42 of Set 11 | rincon
# Processing Record 43 of Set 11 | glens falls
# Processing Record 44 of Set 11 | paraopeba
# Processing Record 45 of Set 11 | hella
# Processing Record 46 of Set 11 | kutum
# Processing Record 47 of Set 11 | vuktyl
# Processing Record 48 of Set 11 | ornskoldsvik
# Processing Record 49 of Set 11 | titisee-neustadt
# Processing Record 50 of Set 11 | malakal
# Processing Record 1 of Set 12 | ndola
# Processing Record 2 of Set 12 | lisakovsk
# Processing Record 3 of Set 12 | kemijarvi
# Processing Record 4 of Set 12 | akhmeta
# Processing Record 5 of Set 12 | rognan
# Processing Record 6 of Set 12 | prenzlau
# Processing Record 7 of Set 12 | passo fundo
# Processing Record 8 of Set 12 | ormara
# Processing Record 9 of Set 12 | bogovarovo
# Processing Record 10 of Set 12 | lembeni
# Processing Record 11 of Set 12 | arkalokhorion
# City not found. Skipping...
# Processing Record 12 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 12 | yeysk
# Processing Record 14 of Set 12 | coxim
# Processing Record 15 of Set 12 | zorritos
# Processing Record 16 of Set 12 | mingoyo
# Processing Record 17 of Set 12 | porto belo
# Processing Record 18 of Set 12 | micheweni
# Processing Record 19 of Set 12 | jumla
# Processing Record 20 of Set 12 | kidal
# Processing Record 21 of Set 12 | khunti
# Processing Record 22 of Set 12 | adre
# Processing Record 23 of Set 12 | wawa
# Processing Record 24 of Set 12 | zharkent
# Processing Record 25 of Set 12 | mutum
# Processing Record 26 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 27 of Set 12 | puerto narino
# Processing Record 28 of Set 12 | olinda
# Processing Record 29 of Set 12 | sergeyevka
# Processing Record 30 of Set 12 | ekibastuz
# Processing Record 31 of Set 12 | jales
# Processing Record 32 of Set 12 | ntcheu
# Processing Record 33 of Set 12 | danilov
# Processing Record 34 of Set 12 | freeport
# Processing Record 35 of Set 12 | santa cruz
# Processing Record 36 of Set 12 | sao gabriel da cachoeira
# Processing Record 37 of Set 12 | vilcun
# Processing Record 38 of Set 12 | oussouye
# Processing Record 39 of Set 12 | bardiyah
# Processing Record 40 of Set 12 | san-pedro
# Processing Record 41 of Set 12 | mogadishu
# Processing Record 42 of Set 12 | kebemer
# City not found. Skipping...
# Processing Record 43 of Set 12 | patamundai
# Processing Record 44 of Set 12 | sao filipe
# Processing Record 45 of Set 12 | benghazi
# Processing Record 46 of Set 12 | berja
# Processing Record 47 of Set 12 | buchanan
# Processing Record 48 of Set 12 | mulanje
# Processing Record 49 of Set 12 | salinas
# Processing Record 50 of Set 12 | constantine
# Processing Record 1 of Set 13 | bama
# Processing Record 2 of Set 13 | sawakin
# Processing Record 3 of Set 13 | trelew
# Processing Record 4 of Set 13 | paramithia
# City not found. Skipping...
# Processing Record 5 of Set 13 | sile
# Processing Record 6 of Set 13 | beni
# Processing Record 7 of Set 13 | grenaa
# Processing Record 8 of Set 13 | damaturu
# Processing Record 9 of Set 13 | usinsk
# Processing Record 10 of Set 13 | zirl
# Processing Record 11 of Set 13 | kargopol
# Processing Record 12 of Set 13 | medea
# Processing Record 13 of Set 13 | edd
# Processing Record 14 of Set 13 | novyy yegorlyk
# Processing Record 15 of Set 13 | sao borja
# Processing Record 16 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 13 | sao sebastiao
# Processing Record 18 of Set 13 | kaniama
# Processing Record 19 of Set 13 | soissons
# Processing Record 20 of Set 13 | sim
# Processing Record 21 of Set 13 | gasa
# Processing Record 22 of Set 13 | grand-santi
# Processing Record 23 of Set 13 | san juan
# Processing Record 24 of Set 13 | kamenka
# Processing Record 25 of Set 13 | vila do maio
# Processing Record 26 of Set 13 | senanga
# Processing Record 27 of Set 13 | honavar
# Processing Record 28 of Set 13 | kayerkan
# Processing Record 29 of Set 13 | ous
# Processing Record 30 of Set 13 | ouro preto do oeste
# Processing Record 31 of Set 13 | shenkursk
# Processing Record 32 of Set 13 | shatsk
# Processing Record 33 of Set 13 | naron
# Processing Record 34 of Set 13 | sakakah
# Processing Record 35 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 36 of Set 13 | hun
# Processing Record 37 of Set 13 | kisangani
# Processing Record 38 of Set 13 | carlos barbosa
# Processing Record 39 of Set 13 | cafarnaum
# Processing Record 40 of Set 13 | axim
# Processing Record 41 of Set 13 | mosquera
# Processing Record 42 of Set 13 | valdivia
# Processing Record 43 of Set 13 | prieska
# Processing Record 44 of Set 13 | bajil
# Processing Record 45 of Set 13 | onega
# Processing Record 46 of Set 13 | piranhas
# Processing Record 47 of Set 13 | ilebo
# Processing Record 48 of Set 13 | liwale
# Processing Record 49 of Set 13 | urrao
# Processing Record 50 of Set 13 | benin
# Processing Record 1 of Set 14 | general roca
# Processing Record 2 of Set 14 | charlottesville
# Processing Record 3 of Set 14 | lodja
# Processing Record 4 of Set 14 | ipixuna
# Processing Record 5 of Set 14 | holetown
# Processing Record 6 of Set 14 | verkh-suetka
# Processing Record 7 of Set 14 | colquechaca
# Processing Record 8 of Set 14 | tiznit
# Processing Record 9 of Set 14 | carndonagh
# Processing Record 10 of Set 14 | baie-comeau
# Processing Record 11 of Set 14 | lamu
# Processing Record 12 of Set 14 | koslan
# Processing Record 13 of Set 14 | san antonio
# Processing Record 14 of Set 14 | constitucion
# Processing Record 15 of Set 14 | pasni
# Processing Record 16 of Set 14 | paita
# Processing Record 17 of Set 14 | viedma
# Processing Record 18 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 14 | escanaba
# Processing Record 20 of Set 14 | karkal
# Processing Record 21 of Set 14 | mungaa
# Processing Record 22 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 14 | manaure
# Processing Record 24 of Set 14 | takoradi
# Processing Record 25 of Set 14 | matagami
# Processing Record 26 of Set 14 | fort-shevchenko
# Processing Record 27 of Set 14 | gualaquiza
# Processing Record 28 of Set 14 | abu dhabi
# Processing Record 29 of Set 14 | kargasok
# Processing Record 30 of Set 14 | anori
# Processing Record 31 of Set 14 | shetpe
# Processing Record 32 of Set 14 | lyubinskiy
# Processing Record 33 of Set 14 | mvangue
# Processing Record 34 of Set 14 | xuddur
# Processing Record 35 of Set 14 | huancabamba
# Processing Record 36 of Set 14 | beniganj
# Processing Record 37 of Set 14 | sokur
# Processing Record 38 of Set 14 | salobrena
# Processing Record 39 of Set 14 | gumushane
# City not found. Skipping...
# Processing Record 40 of Set 14 | najran
# Processing Record 41 of Set 14 | carauari
# Processing Record 42 of Set 14 | harindanga
# Processing Record 43 of Set 14 | sechura
# Processing Record 44 of Set 14 | arlit
# Processing Record 45 of Set 14 | igurusi
# Processing Record 46 of Set 14 | kars
# Processing Record 47 of Set 14 | mrakovo
# Processing Record 48 of Set 14 | varhaug
# Processing Record 49 of Set 14 | black river
# Processing Record 50 of Set 14 | chardara
# Processing Record 1 of Set 15 | cap malheureux
# Processing Record 2 of Set 15 | porto novo
# Processing Record 3 of Set 15 | korla
# Processing Record 4 of Set 15 | pratapgarh
# Processing Record 5 of Set 15 | pechenga
# Processing Record 6 of Set 15 | elizabeth city
# Processing Record 7 of Set 15 | omboue
# Processing Record 8 of Set 15 | havelock
# Processing Record 9 of Set 15 | sacile
# Processing Record 10 of Set 15 | floro
# Processing Record 11 of Set 15 | porangatu
# Processing Record 12 of Set 15 | guarapari
# Processing Record 13 of Set 15 | ciudad bolivar
# Processing Record 14 of Set 15 | dogondoutchi
# Processing Record 15 of Set 15 | cascais
# Processing Record 16 of Set 15 | monrovia
# Processing Record 17 of Set 15 | antigonish
# Processing Record 18 of Set 15 | santa cruz de tenerife
# Processing Record 19 of Set 15 | turayf
# Processing Record 20 of Set 15 | rawson
# Processing Record 21 of Set 15 | kushmurun
# Processing Record 22 of Set 15 | taltal
# Processing Record 23 of Set 15 | robertsport
# Processing Record 24 of Set 15 | obuasi
# Processing Record 25 of Set 15 | yuzhnyy
# Processing Record 26 of Set 15 | wamba
# Processing Record 27 of Set 15 | galabovo
# Processing Record 28 of Set 15 | marsa matruh
# Processing Record 29 of Set 15 | kirillov
# Processing Record 30 of Set 15 | ojhar
# Processing Record 31 of Set 15 | stribro
# Processing Record 32 of Set 15 | casalpusterlengo
# Processing Record 33 of Set 15 | ati
# Processing Record 34 of Set 15 | la romana
# Processing Record 35 of Set 15 | grahamstown
# Processing Record 36 of Set 15 | velsk
# Processing Record 37 of Set 15 | santa marta
# Processing Record 38 of Set 15 | iralaya
# Processing Record 39 of Set 15 | mandali
# Processing Record 40 of Set 15 | la macarena
# Processing Record 41 of Set 15 | san miguel
# Processing Record 42 of Set 15 | orumiyeh
# Processing Record 43 of Set 15 | berbera
# Processing Record 44 of Set 15 | mafinga
# Processing Record 45 of Set 15 | iquique
# Processing Record 46 of Set 15 | eastleigh
# Processing Record 47 of Set 15 | point pedro
# Processing Record 48 of Set 15 | aksehir
# Processing Record 49 of Set 15 | presidencia roque saenz pena
# Processing Record 50 of Set 15 | baghdad
# Processing Record 1 of Set 16 | uwayl
# City not found. Skipping...
# Processing Record 2 of Set 16 | bongandanga
# Processing Record 3 of Set 16 | qurbah
# City not found. Skipping...
# Processing Record 4 of Set 16 | waw
# Processing Record 5 of Set 16 | villa rica
# Processing Record 6 of Set 16 | san ignacio
# Processing Record 7 of Set 16 | fort wellington
# Processing Record 8 of Set 16 | gemena
# Processing Record 9 of Set 16 | baraolt
# Processing Record 10 of Set 16 | aktau
# Processing Record 11 of Set 16 | north augusta
# Processing Record 12 of Set 16 | tonj
# Processing Record 13 of Set 16 | talcahuano
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 703

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hermanus -34.4187  19.2345     57.79        85           0
# 1        Ushuaia -54.8000 -68.3000     58.66        44          20
# 2          Tabou   4.4230  -7.3528     79.12        81         100
# 3  Marsh Harbour  26.5412 -77.0636     79.29        70          52
# 4      Bathsheba  13.2167 -59.5167     84.81        74          20
# 5   Longyearbyen  78.2186  15.6401     26.44        80          75
# 6          Sinop  41.7711  34.8709     45.28        87           6
# 7        Luangwa -15.6167  30.4167     84.31        45          22
# 8      Bonavista  48.6499 -53.1147     35.17        69         100
# 9       Emborion  40.4833  21.5500     49.30        94          85
#
#    Wind Speed Country      Description
# 0        0.92      ZA        clear sky
# 1       14.97      AR       few clouds
# 2        6.49      CI  overcast clouds
# 3        6.78      BS    broken clouds
# 4       18.41      BB       few clouds
# 5       10.36      SJ    broken clouds
# 6        2.55      TR        clear sky
# 7        1.28      ZM       few clouds
# 8       11.21      CA  overcast clouds
# 9        0.81      GR  overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hermanus      ZA -34.4187  19.2345     57.79        85           0
# 1        Ushuaia      AR -54.8000 -68.3000     58.66        44          20
# 2          Tabou      CI   4.4230  -7.3528     79.12        81         100
# 3  Marsh Harbour      BS  26.5412 -77.0636     79.29        70          52
# 4      Bathsheba      BB  13.2167 -59.5167     84.81        74          20
# 5   Longyearbyen      SJ  78.2186  15.6401     26.44        80          75
# 6          Sinop      TR  41.7711  34.8709     45.28        87           6
# 7        Luangwa      ZM -15.6167  30.4167     84.31        45          22
# 8      Bonavista      CA  48.6499 -53.1147     35.17        69         100
# 9       Emborion      GR  40.4833  21.5500     49.30        94          85
#
#    Wind Speed      Description
# 0        0.92        clear sky
# 1       14.97       few clouds
# 2        6.49  overcast clouds
# 3        6.78    broken clouds
# 4       18.41       few clouds
# 5       10.36    broken clouds
# 6        2.55        clear sky
# 7        1.28       few clouds
# 8       11.21  overcast clouds
# 9        0.81  overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 703 entries, 0 to 702
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         703 non-null    object
#  1   Country      703 non-null    object
#  2   Lat          703 non-null    float64
#  3   Lng          703 non-null    float64
#  4   Max Temp     703 non-null    float64
#  5   Humidity     703 non-null    int64
#  6   Cloudiness   703 non-null    int64
#  7   Wind Speed   703 non-null    float64
#  8   Description  703 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 49.6+ KB

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
file_name = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(file_name)
